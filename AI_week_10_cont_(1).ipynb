# %% [markdown]
# <a href="https://colab.research.google.com/github/trinhminhtris/ANN/blob/main/AI_week_10_cont_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/AI/pima_indians_diabetes.csv')
data.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
import seaborn as sns
X = data.iloc[:, 0:8]
y = data.iloc[:, 8]
sns.pairplot(X)

# %%
from keras.models import Sequential
from keras. layers import Dense
model = Sequential()
model.add(Dense(12, activation = 'relu', input_shape = (8,)))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, y, epochs = 150, batch_size = 10)
_,accuracy = model.evaluate(X, y)
print('Do chinh xac cua mo hinh: %2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 4.8849 - accuracy: 0.6271
# Epoch 2/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.8118 - accuracy: 0.5593
# Epoch 3/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.4888 - accuracy: 0.5671
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.3047 - accuracy: 0.5658
# Epoch 5/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.1360 - accuracy: 0.5854
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9613 - accuracy: 0.5971
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8366 - accuracy: 0.6532
# Epoch 8/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7780 - accuracy: 0.6441
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7407 - accuracy: 0.6441
# Epoch 10/150
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(X)
model = Sequential()
model.add(Dense(12, activation = 'relu', input_shape = (8,)))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, y, epochs = 1000, batch_size = 10)
_,accuracy = model.evaluate(x, y)
print('Do chinh xac cua mo hinh: %2f' % (accuracy*100))
# Out:
# Epoch 1/1000
# 77/77 [==============================] - 4s 10ms/step - loss: 5.4988 - accuracy: 0.4198
# Epoch 2/1000
# 77/77 [==============================] - 0s 4ms/step - loss: 3.2180 - accuracy: 0.4133
# Epoch 3/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 2.5634 - accuracy: 0.4029
# Epoch 4/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 2.0904 - accuracy: 0.4120
# Epoch 5/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 1.6919 - accuracy: 0.4420
# Epoch 6/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 1.3751 - accuracy: 0.4928
# Epoch 7/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 1.1481 - accuracy: 0.5072
# Epoch 8/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9534 - accuracy: 0.5619
# Epoch 9/1000
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7698 - accuracy: 0.5984
# Epoch 10/1000
# ...
