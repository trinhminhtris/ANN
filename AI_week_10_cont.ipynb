# %% [markdown]
# <a href="https://colab.research.google.com/github/trinhminhtris/ANN/blob/main/AI_week_10_cont.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
folder = '/content/drive/MyDrive/AI/AI_image/'
for i in range (76):
  plt.subplot(19, 4, i+1)
  filename = folder + 'Tri'+ str(i+1) + '.jpg'
  img = imread(filename)
  plt.imshow(img)
plt.show()

# %%
for i in range (59):
  plt.subplot(19, 4, i+1)
  filename = folder + 'Thinh ('+ str(i+1) + ').jpg'
  img = imread(filename)
  plt.imshow(img)
plt.show()

# %%
for i in range (10):
  plt.subplot(5, 2, i+1)
  filename1 = folder + str(i+1) + '.jpg'
  img1 = imread(filename1)
  plt.imshow(img1)
plt.show()

# %%
from os import listdir
import numpy as np
from numpy import asarray
from numpy import save
from keras.utils import load_img, img_to_array
#from keras.preprocessing.image import load_img, img_to_array

folder = '/content/drive/MyDrive/AI/AI_image/'
photos, labels = list(), list()
for file in listdir(folder): # đọc tất cả file trong folder
  output = 0.0
  if file.startswith('Tri'):
    output = 1.0
  if file.startswith('Thinh'):
    output = 2.0
  img = load_img(folder + file)
  photo = img_to_array(img)
  photos.append(photo)
  labels.append(output)
photos = asarray(photo)
labels = asarray(labels)
print(photos.shape, labels.shape)
save('Tri_Thinh_photos.npy', photos)
save('Tri_Thinh_labels.npy', labels)
# Out:
# (40, 30, 3) (146,)
